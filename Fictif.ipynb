# %%
import pandas as pd

data = {
    'nom_client': [
        'Château Margaux', 'Domaine Lefebvre', 'Cave Cooperative du Sud',
        'Vignobles Martin', 'Maison Dupont', 'Château Margaux',
        'Domaine Lefebvre', 'Les Caves Réunies', 'Vignobles Martin',
        'Maison Dupont'
    ],
    'date_commande': [
        '05/01/2024', '12/01/2024', '20/01/2024',
        '03/02/2024', '14/02/2024', '28/02/2024',
        '10/03/2024', '15/03/2024', '22/03/2024',
        '01/04/2024'
    ],
    'prix': [1200.00, 850.50, 3200.00, 450.00, 980.00,
             1500.00, 620.00, 2750.00, 390.00, 1100.00],
    'type_bouchon': [
        'Liège naturel', 'Liège aggloméré', 'Liège naturel',
        'Synthétique', 'Liège naturel', 'Liège naturel',
        'Synthétique', 'Liège aggloméré', 'Liège aggloméré',
        'Liège naturel'
    ],
    'lieu': [
        'Bordeaux', 'Bourgogne', 'Languedoc',
        'Bordeaux', 'Champagne', 'Bordeaux',
        'Bourgogne', 'Provence', 'Bordeaux',
        'Champagne'
    ]
}

client_ids = ['C001', 'C002', 'C003', 'C004', 'C005',
              'C006', 'C007', 'C008', 'C009', 'C010']

df = pd.DataFrame(data, index=client_ids)
df.index.name = 'client_id'

print(df)
df.head(10)
# Out:
#                         nom_client date_commande    prix     type_bouchon  \
# client_id
# C001               Château Margaux    05/01/2024  1200.0    Liège naturel
# C002              Domaine Lefebvre    12/01/2024   850.5  Liège aggloméré
# C003       Cave Cooperative du Sud    20/01/2024  3200.0    Liège naturel
# C004              Vignobles Martin    03/02/2024   450.0      Synthétique
# C005                 Maison Dupont    14/02/2024   980.0    Liège naturel
# C006               Château Margaux    28/02/2024  1500.0    Liège naturel
# C007              Domaine Lefebvre    10/03/2024   620.0      Synthétique
# C008             Les Caves Réunies    15/03/2024  2750.0  Liège aggloméré
# C009              Vignobles Martin    22/03/2024   390.0  Liège aggloméré
# C010                 Maison Dupont    01/04/2024  1100.0    Liège naturel
#
#                 lieu
# client_id
# C001        Bordeaux
# C002       Bourgogne
# C003       Languedoc
# C004        Bordeaux
# C005       Champagne
# C006        Bordeaux
# C007       Bourgogne
# C008        Provence
# C009        Bordeaux
# C010       Champagne
#                         nom_client date_commande    prix     type_bouchon  \
# client_id
# C001               Château Margaux    05/01/2024  1200.0    Liège naturel
# C002              Domaine Lefebvre    12/01/2024   850.5  Liège aggloméré
# C003       Cave Cooperative du Sud    20/01/2024  3200.0    Liège naturel
# C004              Vignobles Martin    03/02/2024   450.0      Synthétique
# C005                 Maison Dupont    14/02/2024   980.0    Liège naturel
# C006               Château Margaux    28/02/2024  1500.0    Liège naturel
# C007              Domaine Lefebvre    10/03/2024   620.0      Synthétique
# C008             Les Caves Réunies    15/03/2024  2750.0  Liège aggloméré
# C009              Vignobles Martin    22/03/2024   390.0  Liège aggloméré
# C010                 Maison Dupont    01/04/2024  1100.0    Liège naturel
#
#                 lieu
# client_id
# C001        Bordeaux
# C002       Bourgogne
# C003       Languedoc
# C004        Bordeaux
# C005       Champagne
# C006        Bordeaux
# C007       Bourgogne
# C008        Provence
# C009        Bordeaux
# C010       Champagne
